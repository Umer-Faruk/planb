# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('CustomerData.csv')
df1 = df1.bfill()

# !pip install pyfpgrowth
import pyfpgrowth as fpg
records = []

for i in range(len(df1)):
    record = []
    for j in range(len(df1.columns)):
        if df1.values[i, j]:
            record.append(df1.columns[j])
    records.append(record)

itemsets = fpg.find_frequent_patterns(records, 0.03)

# %%
itemsets
# Out:
# {('customer_id',): 60,
#  ('name',): 60,
#  ('gender',): 60,
#  ('age',): 58,
#  ('annual income (lakhs)',): 60,
#  ('spending score',): 60,
#  ('items purchased (monthly)',): 60,
#  ('country',): 60,
#  ('category',): 60,
#  ('purchase type ',): 60,
#  ('customer_id', 'name'): 60,
#  ('customer_id', 'gender'): 60,
#  ('age', 'customer_id'): 58,
#  ('annual income (lakhs)', 'customer_id'): 60,
#  ('customer_id', 'spending score'): 60,
#  ('customer_id', 'items purchased (monthly)'): 60,
#  ('country', 'customer_id'): 60,
#  ('category', 'customer_id'): 60,
#  ('customer_id', 'purchase type '): 60,
#  ('gender', 'name'): 60,
#  ('age', 'name'): 58,
#  ('annual income (lakhs)', 'name'): 60,
#  ('name', 'spending score'): 60,
#  ('items purchased (monthly)', 'name'): 60,
#  ('country', 'name'): 60,
#  ('category', 'name'): 60,
#  ('name', 'purchase type '): 60,
#  ('age', 'gender'): 58,
#  ('annual income (lakhs)', 'gender'): 60,
#  ('gender', 'spending score'): 60,
#  ('gender', 'items purchased (monthly)'): 60,
#  ('country', 'gender'): 60,
#  ('category', 'gender'): 60,
#  ('gender', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)'): 58,
#  ('age', 'spending score'): 58,
#  ('age', 'items purchased (monthly)'): 58,
#  ('age', 'country'): 58,
#  ('age', 'category'): 58,
#  ('age', 'purchase type '): 58,
#  ('annual income (lakhs)', 'spending score'): 60,
#  ('annual income (lakhs)', 'items purchased (monthly)'): 60,
#  ('annual income (lakhs)', 'country'): 60,
#  ('annual income (lakhs)', 'category'): 60,
#  ('annual income (lakhs)', 'purchase type '): 60,
#  ('items purchased (monthly)', 'spending score'): 60,
#  ('country', 'spending score'): 60,
#  ('category', 'spending score'): 60,
#  ('purchase type ', 'spending score'): 60,
#  ('country', 'items purchased (monthly)'): 60,
#  ('category', 'items purchased (monthly)'): 60,
#  ('items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'country'): 60,
#  ('country', 'purchase type '): 60,
#  ('category', 'purchase type '): 60,
#  ('customer_id', 'gender', 'name'): 60,
#  ('age', 'customer_id', 'name'): 58,
#  ('annual income (lakhs)', 'customer_id', 'name'): 60,
#  ('customer_id', 'name', 'spending score'): 60,
#  ('customer_id', 'items purchased (monthly)', 'name'): 60,
#  ('country', 'customer_id', 'name'): 60,
#  ('category', 'customer_id', 'name'): 60,
#  ('customer_id', 'name', 'purchase type '): 60,
#  ('age', 'customer_id', 'gender'): 58,
#  ('annual income (lakhs)', 'customer_id', 'gender'): 60,
#  ('customer_id', 'gender', 'spending score'): 60,
#  ('customer_id', 'gender', 'items purchased (monthly)'): 60,
#  ('country', 'customer_id', 'gender'): 60,
#  ('category', 'customer_id', 'gender'): 60,
#  ('customer_id', 'gender', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'customer_id'): 58,
#  ('age', 'customer_id', 'spending score'): 58,
#  ('age', 'customer_id', 'items purchased (monthly)'): 58,
#  ('age', 'country', 'customer_id'): 58,
#  ('age', 'category', 'customer_id'): 58,
#  ('age', 'customer_id', 'purchase type '): 58,
#  ('annual income (lakhs)', 'customer_id', 'spending score'): 60,
#  ('annual income (lakhs)', 'customer_id', 'items purchased (monthly)'): 60,
#  ('annual income (lakhs)', 'country', 'customer_id'): 60,
#  ('annual income (lakhs)', 'category', 'customer_id'): 60,
#  ('annual income (lakhs)', 'customer_id', 'purchase type '): 60,
#  ('customer_id', 'items purchased (monthly)', 'spending score'): 60,
#  ('country', 'customer_id', 'spending score'): 60,
#  ('category', 'customer_id', 'spending score'): 60,
#  ('customer_id', 'purchase type ', 'spending score'): 60,
#  ('country', 'customer_id', 'items purchased (monthly)'): 60,
#  ('category', 'customer_id', 'items purchased (monthly)'): 60,
#  ('customer_id', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'country', 'customer_id'): 60,
#  ('country', 'customer_id', 'purchase type '): 60,
#  ('category', 'customer_id', 'purchase type '): 60,
#  ('age', 'gender', 'name'): 58,
#  ('annual income (lakhs)', 'gender', 'name'): 60,
#  ('gender', 'name', 'spending score'): 60,
#  ('gender', 'items purchased (monthly)', 'name'): 60,
#  ('country', 'gender', 'name'): 60,
#  ('category', 'gender', 'name'): 60,
#  ('gender', 'name', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'name'): 58,
#  ('age', 'name', 'spending score'): 58,
#  ('age', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'country', 'name'): 58,
#  ('age', 'category', 'name'): 58,
#  ('age', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)', 'name', 'spending score'): 60,
#  ('annual income (lakhs)', 'items purchased (monthly)', 'name'): 60,
#  ('annual income (lakhs)', 'country', 'name'): 60,
#  ('annual income (lakhs)', 'category', 'name'): 60,
#  ('annual income (lakhs)', 'name', 'purchase type '): 60,
#  ('items purchased (monthly)', 'name', 'spending score'): 60,
#  ('country', 'name', 'spending score'): 60,
#  ('category', 'name', 'spending score'): 60,
#  ('name', 'purchase type ', 'spending score'): 60,
#  ('country', 'items purchased (monthly)', 'name'): 60,
#  ('category', 'items purchased (monthly)', 'name'): 60,
#  ('items purchased (monthly)', 'name', 'purchase type '): 60,
#  ('category', 'country', 'name'): 60,
#  ('country', 'name', 'purchase type '): 60,
#  ('category', 'name', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'gender'): 58,
#  ('age', 'gender', 'spending score'): 58,
#  ('age', 'gender', 'items purchased (monthly)'): 58,
#  ('age', 'country', 'gender'): 58,
#  ('age', 'category', 'gender'): 58,
#  ('age', 'gender', 'purchase type '): 58,
#  ('annual income (lakhs)', 'gender', 'spending score'): 60,
#  ('annual income (lakhs)', 'gender', 'items purchased (monthly)'): 60,
#  ('annual income (lakhs)', 'country', 'gender'): 60,
#  ('annual income (lakhs)', 'category', 'gender'): 60,
#  ('annual income (lakhs)', 'gender', 'purchase type '): 60,
#  ('gender', 'items purchased (monthly)', 'spending score'): 60,
#  ('country', 'gender', 'spending score'): 60,
#  ('category', 'gender', 'spending score'): 60,
#  ('gender', 'purchase type ', 'spending score'): 60,
#  ('country', 'gender', 'items purchased (monthly)'): 60,
#  ('category', 'gender', 'items purchased (monthly)'): 60,
#  ('gender', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'country', 'gender'): 60,
#  ('country', 'gender', 'purchase type '): 60,
#  ('category', 'gender', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'items purchased (monthly)'): 58,
#  ('age', 'annual income (lakhs)', 'country'): 58,
#  ('age', 'annual income (lakhs)', 'category'): 58,
#  ('age', 'annual income (lakhs)', 'purchase type '): 58,
#  ('age', 'items purchased (monthly)', 'spending score'): 58,
#  ('age', 'country', 'spending score'): 58,
#  ('age', 'category', 'spending score'): 58,
#  ('age', 'purchase type ', 'spending score'): 58,
#  ('age', 'country', 'items purchased (monthly)'): 58,
#  ('age', 'category', 'items purchased (monthly)'): 58,
#  ('age', 'items purchased (monthly)', 'purchase type '): 58,
#  ('age', 'category', 'country'): 58,
#  ('age', 'country', 'purchase type '): 58,
#  ('age', 'category', 'purchase type '): 58,
#  ('annual income (lakhs)', 'items purchased (monthly)', 'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'spending score'): 60,
#  ('annual income (lakhs)', 'category', 'spending score'): 60,
#  ('annual income (lakhs)', 'purchase type ', 'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'items purchased (monthly)'): 60,
#  ('annual income (lakhs)', 'category', 'items purchased (monthly)'): 60,
#  ('annual income (lakhs)', 'items purchased (monthly)', 'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country'): 60,
#  ('annual income (lakhs)', 'country', 'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'purchase type '): 60,
#  ('country', 'items purchased (monthly)', 'spending score'): 60,
#  ('category', 'items purchased (monthly)', 'spending score'): 60,
#  ('items purchased (monthly)', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'spending score'): 60,
#  ('country', 'purchase type ', 'spending score'): 60,
#  ('category', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'items purchased (monthly)'): 60,
#  ('country', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'country', 'purchase type '): 60,
#  ('age', 'customer_id', 'gender', 'name'): 58,
#  ('annual income (lakhs)', 'customer_id', 'gender', 'name'): 60,
#  ('customer_id', 'gender', 'name', 'spending score'): 60,
#  ('customer_id', 'gender', 'items purchased (monthly)', 'name'): 60,
#  ('country', 'customer_id', 'gender', 'name'): 60,
#  ('category', 'customer_id', 'gender', 'name'): 60,
#  ('customer_id', 'gender', 'name', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'customer_id', 'name'): 58,
#  ('age', 'customer_id', 'name', 'spending score'): 58,
#  ('age', 'customer_id', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'country', 'customer_id', 'name'): 58,
#  ('age', 'category', 'customer_id', 'name'): 58,
#  ('age', 'customer_id', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)', 'customer_id', 'name', 'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)', 'country', 'customer_id', 'name'): 60,
#  ('annual income (lakhs)', 'category', 'customer_id', 'name'): 60,
#  ('annual income (lakhs)', 'customer_id', 'name', 'purchase type '): 60,
#  ('customer_id', 'items purchased (monthly)', 'name', 'spending score'): 60,
#  ('country', 'customer_id', 'name', 'spending score'): 60,
#  ('category', 'customer_id', 'name', 'spending score'): 60,
#  ('customer_id', 'name', 'purchase type ', 'spending score'): 60,
#  ('country', 'customer_id', 'items purchased (monthly)', 'name'): 60,
#  ('category', 'customer_id', 'items purchased (monthly)', 'name'): 60,
#  ('customer_id', 'items purchased (monthly)', 'name', 'purchase type '): 60,
#  ('category', 'country', 'customer_id', 'name'): 60,
#  ('country', 'customer_id', 'name', 'purchase type '): 60,
#  ('category', 'customer_id', 'name', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'customer_id', 'gender'): 58,
#  ('age', 'customer_id', 'gender', 'spending score'): 58,
#  ('age', 'customer_id', 'gender', 'items purchased (monthly)'): 58,
#  ('age', 'country', 'customer_id', 'gender'): 58,
#  ('age', 'category', 'customer_id', 'gender'): 58,
#  ('age', 'customer_id', 'gender', 'purchase type '): 58,
#  ('annual income (lakhs)', 'customer_id', 'gender', 'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)', 'country', 'customer_id', 'gender'): 60,
#  ('annual income (lakhs)', 'category', 'customer_id', 'gender'): 60,
#  ('annual income (lakhs)', 'customer_id', 'gender', 'purchase type '): 60,
#  ('customer_id', 'gender', 'items purchased (monthly)', 'spending score'): 60,
#  ('country', 'customer_id', 'gender', 'spending score'): 60,
#  ('category', 'customer_id', 'gender', 'spending score'): 60,
#  ('customer_id', 'gender', 'purchase type ', 'spending score'): 60,
#  ('country', 'customer_id', 'gender', 'items purchased (monthly)'): 60,
#  ('category', 'customer_id', 'gender', 'items purchased (monthly)'): 60,
#  ('customer_id', 'gender', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'country', 'customer_id', 'gender'): 60,
#  ('country', 'customer_id', 'gender', 'purchase type '): 60,
#  ('category', 'customer_id', 'gender', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'customer_id', 'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'customer_id'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'customer_id'): 58,
#  ('age', 'annual income (lakhs)', 'customer_id', 'purchase type '): 58,
#  ('age', 'customer_id', 'items purchased (monthly)', 'spending score'): 58,
#  ('age', 'country', 'customer_id', 'spending score'): 58,
#  ('age', 'category', 'customer_id', 'spending score'): 58,
#  ('age', 'customer_id', 'purchase type ', 'spending score'): 58,
#  ('age', 'country', 'customer_id', 'items purchased (monthly)'): 58,
#  ('age', 'category', 'customer_id', 'items purchased (monthly)'): 58,
#  ('age', 'customer_id', 'items purchased (monthly)', 'purchase type '): 58,
#  ('age', 'category', 'country', 'customer_id'): 58,
#  ('age', 'country', 'customer_id', 'purchase type '): 58,
#  ('age', 'category', 'customer_id', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'customer_id', 'spending score'): 60,
#  ('annual income (lakhs)', 'category', 'customer_id', 'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country', 'customer_id'): 60,
#  ('annual income (lakhs)', 'country', 'customer_id', 'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'customer_id', 'purchase type '): 60,
#  ('country', 'customer_id', 'items purchased (monthly)', 'spending score'): 60,
#  ('category',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'customer_id', 'spending score'): 60,
#  ('country', 'customer_id', 'purchase type ', 'spending score'): 60,
#  ('category', 'customer_id', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'customer_id', 'items purchased (monthly)'): 60,
#  ('country', 'customer_id', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('category', 'country', 'customer_id', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'gender', 'name'): 58,
#  ('age', 'gender', 'name', 'spending score'): 58,
#  ('age', 'gender', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'country', 'gender', 'name'): 58,
#  ('age', 'category', 'gender', 'name'): 58,
#  ('age', 'gender', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)', 'gender', 'name', 'spending score'): 60,
#  ('annual income (lakhs)', 'gender', 'items purchased (monthly)', 'name'): 60,
#  ('annual income (lakhs)', 'country', 'gender', 'name'): 60,
#  ('annual income (lakhs)', 'category', 'gender', 'name'): 60,
#  ('annual income (lakhs)', 'gender', 'name', 'purchase type '): 60,
#  ('gender', 'items purchased (monthly)', 'name', 'spending score'): 60,
#  ('country', 'gender', 'name', 'spending score'): 60,
#  ('category', 'gender', 'name', 'spending score'): 60,
#  ('gender', 'name', 'purchase type ', 'spending score'): 60,
#  ('country', 'gender', 'items purchased (monthly)', 'name'): 60,
#  ('category', 'gender', 'items purchased (monthly)', 'name'): 60,
#  ('gender', 'items purchased (monthly)', 'name', 'purchase type '): 60,
#  ('category', 'country', 'gender', 'name'): 60,
#  ('country', 'gender', 'name', 'purchase type '): 60,
#  ('category', 'gender', 'name', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'name', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'name', 'purchase type '): 58,
#  ('age', 'items purchased (monthly)', 'name', 'spending score'): 58,
#  ('age', 'country', 'name', 'spending score'): 58,
#  ('age', 'category', 'name', 'spending score'): 58,
#  ('age', 'name', 'purchase type ', 'spending score'): 58,
#  ('age', 'country', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'category', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'items purchased (monthly)', 'name', 'purchase type '): 58,
#  ('age', 'category', 'country', 'name'): 58,
#  ('age', 'country', 'name', 'purchase type '): 58,
#  ('age', 'category', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'name', 'spending score'): 60,
#  ('annual income (lakhs)', 'category', 'name', 'spending score'): 60,
#  ('annual income (lakhs)', 'name', 'purchase type ', 'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'items purchased (monthly)', 'name'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country', 'name'): 60,
#  ('annual income (lakhs)', 'country', 'name', 'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'name', 'purchase type '): 60,
#  ('country', 'items purchased (monthly)', 'name', 'spending score'): 60,
#  ('category', 'items purchased (monthly)', 'name', 'spending score'): 60,
#  ('items purchased (monthly)', 'name', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'name', 'spending score'): 60,
#  ('country', 'name', 'purchase type ', 'spending score'): 60,
#  ('category', 'name', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'items purchased (monthly)', 'name'): 60,
#  ('country', 'items purchased (monthly)', 'name', 'purchase type '): 60,
#  ('category', 'items purchased (monthly)', 'name', 'purchase type '): 60,
#  ('category', 'country', 'name', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'gender', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'gender', 'items purchased (monthly)'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'gender'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'gender'): 58,
#  ('age', 'annual income (lakhs)', 'gender', 'purchase type '): 58,
#  ('age', 'gender', 'items purchased (monthly)', 'spending score'): 58,
#  ('age', 'country', 'gender', 'spending score'): 58,
#  ('age', 'category', 'gender', 'spending score'): 58,
#  ('age', 'gender', 'purchase type ', 'spending score'): 58,
#  ('age', 'country', 'gender', 'items purchased (monthly)'): 58,
#  ('age', 'category', 'gender', 'items purchased (monthly)'): 58,
#  ('age', 'gender', 'items purchased (monthly)', 'purchase type '): 58,
#  ('age', 'category', 'country', 'gender'): 58,
#  ('age', 'country', 'gender', 'purchase type '): 58,
#  ('age', 'category', 'gender', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'gender', 'spending score'): 60,
#  ('annual income (lakhs)', 'category', 'gender', 'spending score'): 60,
#  ('annual income (lakhs)', 'gender', 'purchase type ', 'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country', 'gender'): 60,
#  ('annual income (lakhs)', 'country', 'gender', 'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'gender', 'purchase type '): 60,
#  ('country', 'gender', 'items purchased (monthly)', 'spending score'): 60,
#  ('category', 'gender', 'items purchased (monthly)', 'spending score'): 60,
#  ('gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'gender', 'spending score'): 60,
#  ('country', 'gender', 'purchase type ', 'spending score'): 60,
#  ('category', 'gender', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'gender', 'items purchased (monthly)'): 60,
#  ('country', 'gender', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'gender', 'items purchased (monthly)', 'purchase type '): 60,
#  ('category', 'country', 'gender', 'purchase type '): 60,
#  ('age',
#   'annual income (lakhs)',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'purchase type ', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'items purchased (monthly)'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'items purchased (monthly)'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'country'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'purchase type '): 58,
#  ('age', 'country', 'items purchased (monthly)', 'spending score'): 58,
#  ('age', 'category', 'items purchased (monthly)', 'spending score'): 58,
#  ('age', 'items purchased (monthly)', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'country', 'spending score'): 58,
#  ('age', 'country', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'country', 'items purchased (monthly)'): 58,
#  ('age', 'country', 'items purchased (monthly)', 'purchase type '): 58,
#  ('age', 'category', 'items purchased (monthly)', 'purchase type '): 58,
#  ('age', 'category', 'country', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)', 'category', 'country', 'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'purchase type ', 'spending score'): 60,
#  ('annual income (lakhs)', 'category', 'purchase type ', 'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country', 'purchase type '): 60,
#  ('category', 'country', 'items purchased (monthly)', 'spending score'): 60,
#  ('country',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'items purchased (monthly)', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'customer_id', 'gender', 'name'): 58,
#  ('age', 'customer_id', 'gender', 'name', 'spending score'): 58,
#  ('age', 'customer_id', 'gender', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'country', 'customer_id', 'gender', 'name'): 58,
#  ('age', 'category', 'customer_id', 'gender', 'name'): 58,
#  ('age', 'customer_id', 'gender', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)', 'country', 'customer_id', 'gender', 'name'): 60,
#  ('annual income (lakhs)', 'category', 'customer_id', 'gender', 'name'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type '): 60,
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('country', 'customer_id', 'gender', 'name', 'spending score'): 60,
#  ('category', 'customer_id', 'gender', 'name', 'spending score'): 60,
#  ('customer_id', 'gender', 'name', 'purchase type ', 'spending score'): 60,
#  ('country', 'customer_id', 'gender', 'items purchased (monthly)', 'name'): 60,
#  ('category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category', 'country', 'customer_id', 'gender', 'name'): 60,
#  ('country', 'customer_id', 'gender', 'name', 'purchase type '): 60,
#  ('category', 'customer_id', 'gender', 'name', 'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'customer_id', 'name', 'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'customer_id', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'customer_id', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'customer_id', 'name', 'purchase type '): 58,
#  ('age',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age', 'country', 'customer_id', 'name', 'spending score'): 58,
#  ('age', 'category', 'customer_id', 'name', 'spending score'): 58,
#  ('age', 'customer_id', 'name', 'purchase type ', 'spending score'): 58,
#  ('age', 'country', 'customer_id', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'category', 'customer_id', 'items purchased (monthly)', 'name'): 58,
#  ('age',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age', 'category', 'country', 'customer_id', 'name'): 58,
#  ('age', 'country', 'customer_id', 'name', 'purchase type '): 58,
#  ('age', 'category', 'customer_id', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country', 'customer_id', 'name'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'name',
#   'purchase type '): 60,
#  ('country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'customer_id', 'name', 'spending score'): 60,
#  ('country', 'customer_id', 'name', 'purchase type ', 'spending score'): 60,
#  ('category', 'customer_id', 'name', 'purchase type ', 'spending score'): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category', 'country', 'customer_id', 'name', 'purchase type '): 60,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'customer_id', 'gender'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'customer_id', 'gender'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'purchase type '): 58,
#  ('age',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age', 'country', 'customer_id', 'gender', 'spending score'): 58,
#  ('age', 'category', 'customer_id', 'gender', 'spending score'): 58,
#  ('age', 'customer_id', 'gender', 'purchase type ', 'spending score'): 58,
#  ('age', 'country', 'customer_id', 'gender', 'items purchased (monthly)'): 58,
#  ('age', 'category', 'customer_id', 'gender', 'items purchased (monthly)'): 58,
#  ('age',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age', 'category', 'country', 'customer_id', 'gender'): 58,
#  ('age', 'country', 'customer_id', 'gender', 'purchase type '): 58,
#  ('age', 'category', 'customer_id', 'gender', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country', 'customer_id', 'gender'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'purchase type '): 60,
#  ('country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'customer_id', 'gender', 'spending score'): 60,
#  ('country', 'customer_id', 'gender', 'purchase type ', 'spending score'): 60,
#  ('category', 'customer_id', 'gender', 'purchase type ', 'spending score'): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): 60,
#  ('country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('category', 'country', 'customer_id', 'gender', 'purchase type '): 60,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'country', 'customer_id'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'purchase type '): 58,
#  ('age',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age', 'category', 'country', 'customer_id', 'spending score'): 58,
#  ('age', 'country', 'customer_id', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'customer_id', 'purchase type ', 'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)'): 58,
#  ('age',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age', 'category', 'country', 'customer_id', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('age', 'annual income (lakhs)', 'gender', 'name', 'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'gender', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'gender', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'gender', 'name', 'purchase type '): 58,
#  ('age', 'gender', 'items purchased (monthly)', 'name', 'spending score'): 58,
#  ('age', 'country', 'gender', 'name', 'spending score'): 58,
#  ('age', 'category', 'gender', 'name', 'spending score'): 58,
#  ('age', 'gender', 'name', 'purchase type ', 'spending score'): 58,
#  ('age', 'country', 'gender', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'category', 'gender', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'gender', 'items purchased (monthly)', 'name', 'purchase type '): 58,
#  ('age', 'category', 'country', 'gender', 'name'): 58,
#  ('age', 'country', 'gender', 'name', 'purchase type '): 58,
#  ('age', 'category', 'gender', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)', 'country', 'gender', 'name', 'spending score'): 60,
#  ('annual income (lakhs)', 'category', 'gender', 'name', 'spending score'): 60,
#  ('annual income (lakhs)',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'country', 'gender', 'name'): 60,
#  ('annual income (lakhs)', 'country', 'gender', 'name', 'purchase type '): 60,
#  ('annual income (lakhs)', 'category', 'gender', 'name', 'purchase type '): 60,
#  ('country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'gender', 'name', 'spending score'): 60,
#  ('country', 'gender', 'name', 'purchase type ', 'spending score'): 60,
#  ('category', 'gender', 'name', 'purchase type ', 'spending score'): 60,
#  ('category', 'country', 'gender', 'items purchased (monthly)', 'name'): 60,
#  ('country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category', 'country', 'gender', 'name', 'purchase type '): 60,
#  ('age',
#   'annual income (lakhs)',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'name', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'name', 'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'country', 'name'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'name', 'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'name', 'purchase type '): 58,
#  ('age', 'country', 'items purchased (monthly)', 'name', 'spending score'): 58,
#  ('age',
#   'category',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age', 'category', 'country', 'name', 'spending score'): 58,
#  ('age', 'country', 'name', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'name', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'country', 'items purchased (monthly)', 'name'): 58,
#  ('age', 'country', 'items purchased (monthly)', 'name', 'purchase type '): 58,
#  ('age',
#   'category',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age', 'category', 'country', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'name',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'name', 'purchase type ', 'spending score'): 60,
#  ('category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('age',
#   'annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'gender', 'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'gender', 'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'gender',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'country', 'gender'): 58,
#  ('age', 'annual income (lakhs)', 'country', 'gender', 'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'gender', 'purchase type '): 58,
#  ('age',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age', 'category', 'country', 'gender', 'spending score'): 58,
#  ('age', 'country', 'gender', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'gender', 'purchase type ', 'spending score'): 58,
#  ('age', 'category', 'country', 'gender', 'items purchased (monthly)'): 58,
#  ('age',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age', 'category', 'country', 'gender', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('category', 'country', 'gender', 'purchase type ', 'spending score'): 60,
#  ('category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age', 'annual income (lakhs)', 'category', 'country', 'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age', 'annual income (lakhs)', 'category', 'country', 'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'country',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age', 'category', 'country', 'purchase type ', 'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age', 'country', 'customer_id', 'gender', 'name', 'spending score'): 58,
#  ('age', 'category', 'customer_id', 'gender', 'name', 'spending score'): 58,
#  ('age',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age', 'category', 'country', 'customer_id', 'gender', 'name'): 58,
#  ('age', 'country', 'customer_id', 'gender', 'name', 'purchase type '): 58,
#  ('age', 'category', 'customer_id', 'gender', 'name', 'purchase type '): 58,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type '): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type '): 60,
#  ('country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'spending score'): 60,
#  ('country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
# ...
#  ('category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 60,
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): 58,
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 58,
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): 60,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): 58,
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): 58,
#  ...}

# %%
fpg.generate_association_rules(itemsets, 0.7)
# Out:
# {('customer_id',): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('name',): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('gender',): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('age',): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'),
#   1.0),
#  ('annual income (lakhs)',): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('spending score',): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '),
#   0.9666666666666667),
#  ('items purchased (monthly)',): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('country',): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('category',): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('purchase type ',): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'),
#   0.9666666666666667),
#  ('customer_id',
#   'gender'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'customer_id'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('annual income (lakhs)',
#   'customer_id'): (('age',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'name'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('customer_id',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'customer_id'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'gender'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('annual income (lakhs)',
#   'gender'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('gender',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'gender'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'gender'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)'): (('category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'items purchased (monthly)'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'country'): (('annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'category'): (('annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 1.0),
#  ('annual income (lakhs)',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'items purchased (monthly)'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country'): (('age',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category'): (('age',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('items purchased (monthly)',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name'), 0.9666666666666667),
#  ('country',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('items purchased (monthly)',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country'): (('age',
#    'annual income (lakhs)',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'customer_id',
#   'gender'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'customer_id',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'gender',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('customer_id',
#   'gender',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender'): (('age',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'name'): (('age',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'gender',
#   'name'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'gender',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('customer_id',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('gender',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'gender'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'gender',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'gender'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'gender',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'gender',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'customer_id'): (('category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'name'): (('category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'customer_id',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'name',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 1.0),
#  ('age',
#   'customer_id',
#   'items purchased (monthly)'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'items purchased (monthly)',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'country',
#   'customer_id'): (('annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'country',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'customer_id'): (('annual income (lakhs)',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'name'): (('annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'customer_id',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 1.0),
#  ('age',
#   'name',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 1.0),
#  ('annual income (lakhs)',
#   'customer_id',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'name',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)'): (('age',
#    'category',
#    'country',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'customer_id'): (('age',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'name'): (('age',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'customer_id'): (('age',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'name'): (('age',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'name',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'items purchased (monthly)',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('items purchased (monthly)',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('customer_id',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name'), 0.9666666666666667),
#  ('name',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'items purchased (monthly)',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('items purchased (monthly)',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country',
#   'customer_id'): (('age',
#    'annual income (lakhs)',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'gender'): (('category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'gender',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'gender',
#   'items purchased (monthly)'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'country',
#   'gender'): (('annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'gender'): (('annual income (lakhs)',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'gender',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 1.0),
#  ('annual income (lakhs)',
#   'gender',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'gender'): (('age',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'gender'): (('age',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'gender',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'items purchased (monthly)',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'gender',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'gender',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('gender',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name'), 0.9666666666666667),
#  ('country',
#   'gender',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'gender',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'items purchased (monthly)',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country',
#   'gender'): (('age',
#    'annual income (lakhs)',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'gender',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'gender',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'spending score'): (('category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'items purchased (monthly)'): (('category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country'): (('category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category'): (('country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'purchase type '): (('category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 1.0),
#  ('age',
#   'items purchased (monthly)',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'country',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'category',
#   'spending score'): (('annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name'), 1.0),
#  ('age',
#   'country',
#   'items purchased (monthly)'): (('annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'items purchased (monthly)'): (('annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'items purchased (monthly)',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'country'): (('annual income (lakhs)',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'country',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'purchase type '): (('annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 1.0),
#  ('annual income (lakhs)',
#   'items purchased (monthly)',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'spending score'): (('age',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'spending score'): (('age',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'purchase type ',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'items purchased (monthly)'): (('age',
#    'category',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'items purchased (monthly)'): (('age',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'items purchased (monthly)',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country'): (('age',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'purchase type '): (('age',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'purchase type '): (('age',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'items purchased (monthly)',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'items purchased (monthly)',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'gender',
#    'name'), 0.9666666666666667),
#  ('category',
#   'country',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name'), 0.9666666666666667),
#  ('category',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name'), 0.9666666666666667),
#  ('category',
#   'country',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'customer_id',
#    'gender',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'items purchased (monthly)',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'gender',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'items purchased (monthly)',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'gender',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'customer_id',
#    'gender',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender'): (('category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'name'): (('category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'gender',
#   'name'): (('category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'customer_id',
#   'gender',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'name'): (('age',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'customer_id',
#   'gender',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 1.0),
#  ('age',
#   'customer_id',
#   'name',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 1.0),
#  ('age',
#   'gender',
#   'name',
#   'spending score'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type '), 1.0),
#  ('customer_id',
#   'gender',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('age',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'gender',
#   'items purchased (monthly)',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'country',
#   'customer_id',
#   'gender'): (('annual income (lakhs)',
#    'category',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'country',
#   'customer_id',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'country',
#   'gender',
#   'name'): (('annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('country',
#   'customer_id',
#   'gender',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'category',
#   'customer_id',
#   'gender'): (('annual income (lakhs)',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'customer_id',
#   'name'): (('annual income (lakhs)',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('age',
#   'category',
#   'gender',
#   'name'): (('annual income (lakhs)',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 1.0),
#  ('category',
#   'customer_id',
#   'gender',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('age',
#   'customer_id',
#   'gender',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 1.0),
#  ('age',
#   'customer_id',
#   'name',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 1.0),
#  ('age',
#   'gender',
#   'name',
#   'purchase type '): (('annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'spending score'), 1.0),
#  ('customer_id',
#   'gender',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'name',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'gender',
#   'name',
#   'spending score'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): (('age',
#    'category',
#    'country',
#    'name',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'category',
#    'country',
#    'gender',
#    'purchase type ',
#    'spending score'),
#   0.9666666666666667),
#  ('annual income (lakhs)',
#   'gender',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender'): (('age',
#    'category',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'name'): (('age',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'name'): (('age',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender'): (('age',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'name'): (('age',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'name'): (('age',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'customer_id',
#   'name',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'gender',
#   'name',
#   'purchase type '): (('age',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'purchase type '), 0.9666666666666667),
#  ('gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'gender',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('country',
#   'gender',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'gender',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'items purchased (monthly)',
#    'name',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('category',
#   'gender',
#   'name',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type '), 0.9666666666666667),
#  ('customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'items purchased (monthly)',
#    'name'), 0.9666666666666667),
#  ('customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'items purchased (monthly)'), 0.9666666666666667),
#  ('gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'items purchased (monthly)'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'gender',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'gender',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'gender',
#   'items purchased (monthly)',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'country',
#    'customer_id',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'gender',
#    'spending score'), 0.9666666666666667),
#  ('gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'country',
#    'customer_id',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country',
#   'customer_id',
#   'gender'): (('age',
#    'annual income (lakhs)',
#    'items purchased (monthly)',
#    'name',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country',
#   'customer_id',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'gender',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'country',
#   'gender',
#   'name'): (('age',
#    'annual income (lakhs)',
#    'customer_id',
#    'items purchased (monthly)',
#    'purchase type ',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'gender',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'items purchased (monthly)',
#    'name',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'customer_id',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'gender',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('country',
#   'gender',
#   'name',
#   'purchase type '): (('age',
#    'annual income (lakhs)',
#    'category',
#    'customer_id',
#    'items purchased (monthly)',
#    'spending score'), 0.9666666666666667),
#  ('category',
#   'customer_id',
#   'gender',
# ...
#  ('age',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'category', 'customer_id'),
#   1.0),
#  ('country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'annual income (lakhs)', 'category'),
#   0.9666666666666667),
#  ('age',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'country', 'name'), 1.0),
#  ('age',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'country', 'gender'), 1.0),
#  ('age',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'country', 'customer_id'),
#   1.0),
#  ('category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'annual income (lakhs)', 'country'),
#   0.9666666666666667),
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)',
#    'items purchased (monthly)',
#    'name'),
#   1.0),
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)',
#    'gender',
#    'items purchased (monthly)'),
#   1.0),
#  ('age',
#   'category',
#   'country',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)',
#    'customer_id',
#    'items purchased (monthly)'),
#   1.0),
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('age',
#    'annual income (lakhs)',
#    'items purchased (monthly)'),
#   0.9666666666666667),
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): (('annual income (lakhs)', 'name', 'spending score'),
#   1.0),
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('annual income (lakhs)', 'gender', 'spending score'),
#   1.0),
#  ('age',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('annual income (lakhs)',
#    'customer_id',
#    'spending score'),
#   1.0),
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('age', 'annual income (lakhs)', 'spending score'),
#   0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): (('age', 'name', 'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('age', 'gender', 'purchase type '), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('age', 'customer_id', 'purchase type '),
#   0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('age', 'category', 'name'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'category', 'gender'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'category', 'customer_id'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('age', 'country', 'name'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'country', 'gender'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'country', 'customer_id'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): (('age', 'items purchased (monthly)', 'name'),
#   0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'gender', 'items purchased (monthly)'),
#   0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'customer_id', 'items purchased (monthly)'),
#   0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): (('age', 'name', 'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('age', 'gender', 'spending score'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('age', 'customer_id', 'spending score'),
#   0.9666666666666667),
#  ('category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('age', 'annual income (lakhs)', 'name'),
#   0.9666666666666667),
#  ('category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'annual income (lakhs)', 'gender'),
#   0.9666666666666667),
#  ('category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'annual income (lakhs)', 'customer_id'),
#   0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'spending score'): (('gender', 'name', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('customer_id', 'gender', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('category', 'gender', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('category', 'customer_id', 'gender'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('country', 'gender', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('country', 'customer_id', 'gender'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'purchase type ',
#   'spending score'): (('gender', 'items purchased (monthly)', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'name',
#   'purchase type ',
#   'spending score'): (('customer_id', 'gender', 'items purchased (monthly)'),
#   1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type '): (('gender', 'name', 'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('customer_id', 'gender', 'spending score'), 1.0),
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'gender', 'name'), 1.0),
#  ('age',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'customer_id', 'gender'), 1.0),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('age', 'gender', 'name'), 0.9666666666666667),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'customer_id', 'gender'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): (('customer_id', 'name', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('category', 'customer_id', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('country', 'customer_id', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'purchase type ',
#   'spending score'): (('customer_id', 'items purchased (monthly)', 'name'),
#   1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): (('customer_id', 'name', 'spending score'), 1.0),
#  ('age',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'customer_id', 'name'), 1.0),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('age', 'customer_id', 'name'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('customer_id', 'gender', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name'): (('purchase type ', 'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'spending score'): (('name', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'spending score'): (('items purchased (monthly)', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('gender', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('customer_id', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('country', 'purchase type '), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('category', 'purchase type '), 1.0),
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('annual income (lakhs)', 'purchase type '), 1.0),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'spending score'): (('age', 'purchase type '), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('category', 'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('category', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('category', 'items purchased (monthly)'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('category', 'gender'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('category', 'customer_id'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('category', 'country'), 1.0),
#  ('age',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'category'), 1.0),
#  ('annual income (lakhs)',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'category'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('country', 'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type ',
#   'spending score'): (('country', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('country', 'items purchased (monthly)'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('country', 'gender'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('country', 'customer_id'), 1.0),
#  ('age',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'country'), 1.0),
#  ('annual income (lakhs)',
#   'category',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'country'), 0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type '): (('items purchased (monthly)', 'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'purchase type ',
#   'spending score'): (('items purchased (monthly)', 'name'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'name',
#   'purchase type ',
#   'spending score'): (('gender', 'items purchased (monthly)'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('customer_id', 'items purchased (monthly)'), 1.0),
#  ('age',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('annual income (lakhs)', 'items purchased (monthly)'),
#   1.0),
#  ('annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'name',
#   'purchase type ',
#   'spending score'): (('age', 'items purchased (monthly)'),
#   0.9666666666666667),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'gender',
#   'items purchased (monthly)',
#   'purchase type '): (('name', 'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'customer_id',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('gender', 'spending score'), 1.0),
#  ('age',
#   'annual income (lakhs)',
#   'category',
#   'country',
#   'gender',
#   'items purchased (monthly)',
#   'name',
#   'purchase type '): (('customer_id', 'spending score'), 1.0),
#  ...}
