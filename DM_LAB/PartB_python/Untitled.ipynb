# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt

data = pd.read_csv('CustomerData.csv')
# data.info()
# data.head()
# data.tail()
# data.describe()
# data.isna().sum()

# data['gender'].fillna(data.gender.mode()[0],inplace=True)
# data['category'].fillna(data.category.mode()[0],inplace=True)

# data.fillna(data.mean(),inplace=True)
# data.isna().sum()

# data.dropna(axis=0,inplace=True)
# data.drop(columns=('customer_id'),axis=1,inplace=True)
# data.head()




 # sns.boxplot(data=data, x='items purchased (monthly)')
# sns.scatterplot(data=data, x='annual income (lakhs)',y='items purchased (monthly)', hue='gender')
# sns.barplot(data=data, x='age', y='items purchased (monthly)')

# %%
data.head()
# Out:
#    customer_id      name  gender   age  annual income (lakhs)  spending score  \
# 0            1     Edith  Female   NaN                   40.9              27
# 1            2  Sinclair    Male  53.0                    NaN              42
# 2            3     Enoch    Male  22.0                    NaN              70
# 3            4   Lorenzo    Male   9.0                   18.5              68
# 4            5    Damian    Male  55.0                   18.4              69
#
#    items purchased (monthly)      country   category purchase type
# 0                         62         Iran       Baby        offline
# 1                         47        China        NaN         online
# 2                         26        China  Computers        offline
# 3                         80       Russia        NaN         online
# 4                         89  Philippines   Jewelery        offline

# %%
data.describe()
# Out:
#        customer_id        age  annual income (lakhs)  spending score  \
# count    60.000000  55.000000              52.000000       60.000000
# mean     30.500000  29.945455              35.578846       46.016667
# std      17.464249  18.669066              14.654964       26.076479
# min       1.000000   0.000000              11.200000        2.000000
# 25%      15.750000  15.000000              22.225000       27.000000
# 50%      30.500000  31.000000              35.150000       43.500000
# 75%      45.250000  46.000000              50.325000       68.250000
# max      60.000000  59.000000              60.000000      100.000000
#
#        items purchased (monthly)
# count                  60.000000
# mean                   51.333333
# std                    30.628815
# min                     1.000000
# 25%                    25.750000
# 50%                    57.000000
# 75%                    75.250000
# max                   100.000000

# %%
data.isna().sum()
# Out:
# customer_id                   0
# name                          0
# gender                       10
# age                           5
# annual income (lakhs)         8
# spending score                0
# items purchased (monthly)     0
# country                       0
# category                     13
# purchase type                 0
# dtype: int64

# %%
data['gender'].fillna(data.gender.mode()[0],inplace=True)
data.head(50)
# Out:
#     customer_id        name  gender   age  annual income (lakhs)  \
# 0             1       Edith  Female   NaN                   40.9
# 1             2    Sinclair    Male  53.0                    NaN
# 2             3       Enoch    Male  22.0                    NaN
# 3             4     Lorenzo    Male   9.0                   18.5
# 4             5      Damian    Male  55.0                   18.4
# 5             6       Drona  Female  52.0                   54.8
# 6             7   Sylvester    Male  19.0                   21.4
# 7             8        Olag    Male  23.0                   58.2
# 8             9    Timothee    Male   0.0                   44.0
# 9            10      Velvet    Male   3.0                   35.4
# 10           11     Jerrold    Male   8.0                   40.6
# 11           12      Tulley    Male  54.0                   51.0
# 12           13        Myca    Male  10.0                   22.5
# 13           14   Westbrook    Male   NaN                   32.2
# 14           15      Hurlee    Male  33.0                    NaN
# 15           16       Maggy  Female  58.0                   36.0
# 16           17      Jerald    Male  59.0                   26.4
# 17           18       Lyman    Male  34.0                   17.2
# 18           19      Jennee  Female  42.0                   60.0
# 19           20  Petronilla    Male  57.0                   54.1
# 20           21       Drake    Male  21.0                   37.1
# 21           22      Cullin    Male  12.0                   26.0
# 22           23     Valaria  Female  15.0                    NaN
# 23           24        Jard    Male   5.0                   48.4
# 24           25        Joni    Male  40.0                   23.9
# 25           26          Ad    Male   4.0                   14.4
# 26           27       Sacha  Female  46.0                   11.2
# 27           28       Nessa  Female  55.0                   37.6
# 28           29       Brant    Male  35.0                   53.7
# 29           30       Edita    Male  20.0                   45.5
# 30           31       Kelby    Male  56.0                   50.1
# 31           32       Legra  Female  47.0                   55.2
# 32           33     Spencer    Male  57.0                   18.9
# 33           34    Olivette  Female   NaN                   19.0
# 34           35      Rainer    Male  25.0                    NaN
# 35           36      Gretna  Female  16.0                   55.2
# 36           37    Aloysius    Male   1.0                   36.2
# 37           38     Darrell    Male  15.0                   31.0
# 38           39     Manfred    Male  11.0                   31.5
# 39           40         Tam    Male  15.0                    NaN
# 40           41    Beatrisa    Male  51.0                   26.6
# 41           42       Shara    Male   4.0                   24.1
# 42           43       Brock    Male  31.0                   15.6
# 43           44      Felice    Male  33.0                    NaN
# 44           45         Ned    Male  39.0                   15.5
# 45           46    Cathrine  Female  25.0                   52.0
# 46           47    Dolorita  Female  41.0                   57.5
# 47           48    Leonanie  Female  46.0                   41.6
# 48           49     Melinda  Female  46.0                   52.8
# 49           50     Andonis    Male  19.0                   30.9
#
#     spending score  items purchased (monthly)         country     category  \
# 0               27                         62            Iran         Baby
# 1               42                         47           China          NaN
# 2               70                         26           China    Computers
# 3               68                         80          Russia          NaN
# 4               69                         89     Philippines     Jewelery
# 5               35                         98       Indonesia        Music
# 6               52                          1           China          NaN
# 7               47                         19        Portugal       Beauty
# 8               23                         65      Uzbekistan  Electronics
# 9               40                         31          Russia        Games
# 10              15                          3           China     Outdoors
# 11               8                         94          Russia         Toys
# 12              70                         11       Indonesia  Electronics
# 13              78                         25   United States     Outdoors
# 14              51                         56          Brazil        Music
# 15               2                         14     Philippines         Toys
# 16              92                         13           China     Clothing
# 17               5                         19   United States        Shoes
# 18              35                         58        Tanzania        Books
# 19              27                         75          Uganda        Books
# 20              22                         68            Iran    Computers
# 21              96                         50           China   Automotive
# 22              82                         84     Philippines     Jewelery
# 23              39                         60        Slovenia       Health
# 24              24                          4           China     Clothing
# 25              29                         58       Indonesia   Automotive
# 26              57                         26     Philippines         Home
# 27             100                         87          Russia         Baby
# 28              59                         42   United States          NaN
# 29              92                         76          Russia  Electronics
# 30              74                         98         Ukraine          NaN
# 31              48                         28          Poland          NaN
# 32              15                         51          Brazil      Grocery
# 33              57                         23       Indonesia         Kids
# 34              63                         94           China     Outdoors
# 35              29                         34         Ukraine        Shoes
# 36              28                         74           China        Music
# 37              49                         96  Czech Republic         Baby
# 38              43                         34       Nicaragua        Music
# 39              65                         61     Philippines          NaN
# 40               4                         81           China       Beauty
# 41              11                          3       Indonesia        Games
# 42              17                         54       Indonesia      Grocery
# 43              41                         90           China          NaN
# 44               4                         64          France          NaN
# 45              73                         39         Reunion       Garden
# 46              44                          6           China    Computers
# 47              12                         97          Brazil        Games
# 48              29                        100       Indonesia          NaN
# 49              32                         59        Maldives      Grocery
#
#    purchase type
# 0         offline
# 1          online
# 2         offline
# 3          online
# 4         offline
# 5         offline
# 6          online
# 7          online
# 8         offline
# 9         offline
# 10        offline
# 11        offline
# 12         online
# 13        offline
# 14         online
# 15         online
# 16         online
# 17         online
# 18        offline
# 19        offline
# 20        offline
# 21        offline
# 22         online
# 23         online
# 24         online
# 25        offline
# 26        offline
# 27         online
# 28        offline
# 29        offline
# 30        offline
# 31         online
# 32        offline
# 33         online
# 34         online
# 35         online
# 36         online
# 37         online
# 38         online
# 39         online
# 40         online
# 41         online
# 42         online
# 43         online
# 44        offline
# 45         online
# 46        offline
# 47        offline
# 48        offline
# 49        offline

# %%
data.isna().sum()
# Out:
# customer_id                   0
# name                          0
# gender                       10
# age                           5
# annual income (lakhs)         8
# spending score                0
# items purchased (monthly)     0
# country                       0
# category                     13
# purchase type                 0
# dtype: int64

# %%
data.isna().sum()
# Out:
# customer_id                  0
# name                         0
# gender                       0
# age                          5
# annual income (lakhs)        8
# spending score               0
# items purchased (monthly)    0
# country                      0
# category                     0
# purchase type                0
# dtype: int64

# %%
data.fillna(data.mean(),inplace=True)
data.head()
# Out:
#        name  gender        age  annual income (lakhs)  spending score  \
# 0     Edith  Female  29.945455              40.900000              27
# 1  Sinclair    Male  53.000000              35.578846              42
# 2     Enoch    Male  22.000000              35.578846              70
# 3   Lorenzo    Male   9.000000              18.500000              68
# 4    Damian    Male  55.000000              18.400000              69
#
#    items purchased (monthly)      country   category purchase type
# 0                         62         Iran       Baby        offline
# 1                         47        China        NaN         online
# 2                         26        China  Computers        offline
# 3                         80       Russia        NaN         online
# 4                         89  Philippines   Jewelery        offline

# %%
data.isna().sum()
# Out:
# customer_id                   0
# name                          0
# gender                       10
# age                           0
# annual income (lakhs)         0
# spending score                0
# items purchased (monthly)     0
# country                       0
# category                     13
# purchase type                 0
# dtype: int64

# %%
data.drop(['customer_id'],axis=1,inplace=True)

# %%
data.head()
# Out:
#        name  gender   age  annual income (lakhs)  spending score  \
# 0     Edith  Female   NaN                   40.9              27
# 1  Sinclair    Male  53.0                    NaN              42
# 2     Enoch    Male  22.0                    NaN              70
# 3   Lorenzo    Male   9.0                   18.5              68
# 4    Damian    Male  55.0                   18.4              69
#
#    items purchased (monthly)      country   category purchase type
# 0                         62         Iran       Baby        offline
# 1                         47        China        NaN         online
# 2                         26        China  Computers        offline
# 3                         80       Russia        NaN         online
# 4                         89  Philippines   Jewelery        offline

# %%
from sklearn.preprocessing import LabelEncoder
data[['gender','purchase type ','category','country']] = data[['gender','purchase type ','category','country']].apply(LabelEncoder().fit_transform)
data.head()
# Out:
#        name  gender        age  annual income (lakhs)  spending score  \
# 0     Edith       0  29.945455              40.900000              27
# 1  Sinclair       1  53.000000              35.578846              42
# 2     Enoch       1  22.000000              35.578846              70
# 3   Lorenzo       1   9.000000              18.500000              68
# 4    Damian       1  55.000000              18.400000              69
#
#    items purchased (monthly)  country  category  purchase type
# 0                         62        7         1               0
# 1                         47        2         2               1
# 2                         26        2         5               0
# 3                         80       16         2               1
# 4                         89       12        12               0

# %%
sns.boxplot(data=data, x='items purchased (monthly)')

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1a10aca6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a10a937b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1a10a42cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a10a7c2e8>]],
#       dtype=object)

# %%
data.plot.bar()

# %%
plt.bar(data['gender'],data['age'])
# Out:
# <BarContainer object of 60 artists>

# %%
import seaborn as sns

# %%
sns.boxplot(data['age'])

# %%
sns.scatterplot(data=data,x='annual income (lakhs)',y='items purchased (monthly)', hue='gender')

# %%
#p3

# %%
dt = pd.read_csv('association_analysis.csv')

# %%
dt.head()
# Out:
#    tid  onion  tomato  potato  bottleguard  beans
# 0    1      1       0       1            0      0
# 1    2      1       0       0            1      1
# 2    3      0       0       1            0      0
# 3    4      0       1       1            1      1
# 4    5      1       1       1            0      0

# %%
dt.columns
# Out:
# Index(['tid', 'onion', 'tomato', 'potato', 'bottleguard', 'beans'], dtype='object')

# %%
dt.values
# Out:
# array([[ 1,  1,  0,  1,  0,  0],
#        [ 2,  1,  0,  0,  1,  1],
#        [ 3,  0,  0,  1,  0,  0],
#        [ 4,  0,  1,  1,  1,  1],
#        [ 5,  1,  1,  1,  0,  0],
#        [ 6,  0,  1,  0,  1,  1],
#        [ 7,  0,  1,  0,  0,  0],
#        [ 8,  1,  0,  1,  0,  0],
#        [ 9,  0,  1,  1,  0,  1],
#        [10,  0,  1,  0,  0,  0],
#        [11,  1,  1,  0,  0,  0],
#        [12,  1,  1,  0,  0,  0],
#        [13,  1,  0,  0,  0,  1],
#        [14,  0,  1,  0,  1,  1],
#        [15,  1,  0,  1,  1,  0],
#        [16,  0,  1,  0,  1,  1],
#        [17,  0,  0,  0,  1,  0],
#        [18,  0,  1,  0,  1,  1],
#        [19,  1,  0,  0,  0,  1],
#        [20,  1,  1,  0,  0,  1],
#        [21,  1,  1,  1,  1,  0],
#        [22,  1,  1,  1,  0,  1],
#        [23,  0,  0,  1,  1,  0],
#        [24,  1,  0,  0,  0,  0],
#        [25,  1,  1,  1,  1,  1],
#        [26,  1,  1,  0,  0,  0],
#        [27,  0,  1,  1,  1,  1],
#        [28,  1,  0,  0,  1,  0],
#        [29,  1,  0,  1,  1,  1],
#        [30,  0,  1,  0,  0,  1],
#        [31,  1,  1,  1,  1,  1],
#        [32,  0,  0,  1,  0,  0],
#        [33,  0,  1,  1,  0,  0],
#        [34,  0,  0,  1,  0,  1],
#        [35,  0,  0,  1,  1,  0],
#        [36,  1,  1,  1,  0,  0],
#        [37,  1,  1,  1,  1,  0],
#        [38,  0,  0,  0,  0,  1],
#        [39,  1,  0,  1,  0,  1],
#        [40,  1,  0,  0,  1,  1],
#        [41,  1,  1,  0,  0,  1],
#        [42,  0,  1,  1,  0,  0],
#        [43,  0,  0,  1,  0,  0],
#        [44,  0,  0,  0,  0,  1],
#        [45,  0,  0,  0,  1,  0],
#        [46,  0,  1,  0,  1,  1],
#        [47,  1,  1,  1,  0,  1],
#        [48,  0,  0,  0,  1,  0],
#        [49,  0,  1,  1,  1,  0],
#        [50,  1,  1,  0,  1,  0],
#        [51,  1,  1,  1,  1,  1]])

# %%
from apyori import apriori

# %%
R=[]
for i in range(len(dt)):
    r=[]
    for j in range(len(dt.columns)):
        if dt.values[i,j]:
            r.append(dt.columns[j])
    R.append(r)

# %%
R
# Out:
# [['tid', 'onion', 'potato'],
#  ['tid', 'onion', 'bottleguard', 'beans'],
#  ['tid', 'potato'],
#  ['tid', 'tomato', 'potato', 'bottleguard', 'beans'],
#  ['tid', 'onion', 'tomato', 'potato'],
#  ['tid', 'tomato', 'bottleguard', 'beans'],
#  ['tid', 'tomato'],
#  ['tid', 'onion', 'potato'],
#  ['tid', 'tomato', 'potato', 'beans'],
#  ['tid', 'tomato'],
#  ['tid', 'onion', 'tomato'],
#  ['tid', 'onion', 'tomato'],
#  ['tid', 'onion', 'beans'],
#  ['tid', 'tomato', 'bottleguard', 'beans'],
#  ['tid', 'onion', 'potato', 'bottleguard'],
#  ['tid', 'tomato', 'bottleguard', 'beans'],
#  ['tid', 'bottleguard'],
#  ['tid', 'tomato', 'bottleguard', 'beans'],
#  ['tid', 'onion', 'beans'],
#  ['tid', 'onion', 'tomato', 'beans'],
#  ['tid', 'onion', 'tomato', 'potato', 'bottleguard'],
#  ['tid', 'onion', 'tomato', 'potato', 'beans'],
#  ['tid', 'potato', 'bottleguard'],
#  ['tid', 'onion'],
#  ['tid', 'onion', 'tomato', 'potato', 'bottleguard', 'beans'],
#  ['tid', 'onion', 'tomato'],
#  ['tid', 'tomato', 'potato', 'bottleguard', 'beans'],
#  ['tid', 'onion', 'bottleguard'],
#  ['tid', 'onion', 'potato', 'bottleguard', 'beans'],
#  ['tid', 'tomato', 'beans'],
#  ['tid', 'onion', 'tomato', 'potato', 'bottleguard', 'beans'],
#  ['tid', 'potato'],
#  ['tid', 'tomato', 'potato'],
#  ['tid', 'potato', 'beans'],
#  ['tid', 'potato', 'bottleguard'],
#  ['tid', 'onion', 'tomato', 'potato'],
#  ['tid', 'onion', 'tomato', 'potato', 'bottleguard'],
#  ['tid', 'beans'],
#  ['tid', 'onion', 'potato', 'beans'],
#  ['tid', 'onion', 'bottleguard', 'beans'],
#  ['tid', 'onion', 'tomato', 'beans'],
#  ['tid', 'tomato', 'potato'],
#  ['tid', 'potato'],
#  ['tid', 'beans'],
#  ['tid', 'bottleguard'],
#  ['tid', 'tomato', 'bottleguard', 'beans'],
#  ['tid', 'onion', 'tomato', 'potato', 'beans'],
#  ['tid', 'bottleguard'],
#  ['tid', 'tomato', 'potato', 'bottleguard'],
#  ['tid', 'onion', 'tomato', 'bottleguard'],
#  ['tid', 'onion', 'tomato', 'potato', 'bottleguard', 'beans']]

# %%
min_sup = 0.03
min_conf = 0.7

rules = apriori(R)

# %%
rules
# Out:
# <generator object apriori at 0x7f1a12424ba0>

# %%
for rul in rules:
#     print(rul[0])
    itm = [i for i in rul[0]]
    print("rule:",itm,"support:",rul[1],"confidence:",rul[2][0][2])
# Out:
# rule: ['beans'] support: 0.49019607843137253 confidence: 0.49019607843137253
# rule: ['bottleguard'] support: 0.47058823529411764 confidence: 0.47058823529411764
# rule: ['onion'] support: 0.5098039215686274 confidence: 0.5098039215686274
# rule: ['potato'] support: 0.5098039215686274 confidence: 0.5098039215686274
# rule: ['tid'] support: 1.0 confidence: 1.0
# rule: ['tomato'] support: 0.5686274509803921 confidence: 0.5686274509803921
# rule: ['beans', 'bottleguard'] support: 0.2549019607843137 confidence: 0.2549019607843137
# rule: ['beans', 'onion'] support: 0.2549019607843137 confidence: 0.2549019607843137
# rule: ['beans', 'potato'] support: 0.21568627450980393 confidence: 0.21568627450980393
# rule: ['tid', 'beans'] support: 0.49019607843137253 confidence: 0.49019607843137253
# rule: ['beans', 'tomato'] support: 0.3137254901960784 confidence: 0.3137254901960784
# rule: ['bottleguard', 'onion'] support: 0.21568627450980393 confidence: 0.21568627450980393
# rule: ['potato', 'bottleguard'] support: 0.23529411764705882 confidence: 0.23529411764705882
# rule: ['tid', 'bottleguard'] support: 0.47058823529411764 confidence: 0.47058823529411764
# rule: ['tomato', 'bottleguard'] support: 0.27450980392156865 confidence: 0.27450980392156865
# rule: ['potato', 'onion'] support: 0.27450980392156865 confidence: 0.27450980392156865
# rule: ['tid', 'onion'] support: 0.5098039215686274 confidence: 0.5098039215686274
# rule: ['tomato', 'onion'] support: 0.29411764705882354 confidence: 0.29411764705882354
# rule: ['tid', 'potato'] support: 0.5098039215686274 confidence: 0.5098039215686274
# rule: ['tomato', 'potato'] support: 0.29411764705882354 confidence: 0.29411764705882354
# rule: ['tid', 'tomato'] support: 0.5686274509803921 confidence: 0.5686274509803921
# rule: ['beans', 'bottleguard', 'onion'] support: 0.11764705882352941 confidence: 0.11764705882352941
# rule: ['beans', 'potato', 'bottleguard'] support: 0.11764705882352941 confidence: 0.11764705882352941
# rule: ['tid', 'beans', 'bottleguard'] support: 0.2549019607843137 confidence: 0.2549019607843137
# rule: ['beans', 'bottleguard', 'tomato'] support: 0.19607843137254902 confidence: 0.19607843137254902
# rule: ['beans', 'potato', 'onion'] support: 0.13725490196078433 confidence: 0.13725490196078433
# rule: ['tid', 'beans', 'onion'] support: 0.2549019607843137 confidence: 0.2549019607843137
# rule: ['beans', 'tomato', 'onion'] support: 0.13725490196078433 confidence: 0.13725490196078433
# rule: ['tid', 'beans', 'potato'] support: 0.21568627450980393 confidence: 0.21568627450980393
# rule: ['beans', 'potato', 'tomato'] support: 0.1568627450980392 confidence: 0.1568627450980392
# rule: ['tid', 'beans', 'tomato'] support: 0.3137254901960784 confidence: 0.3137254901960784
# rule: ['potato', 'bottleguard', 'onion'] support: 0.13725490196078433 confidence: 0.13725490196078433
# rule: ['tid', 'bottleguard', 'onion'] support: 0.21568627450980393 confidence: 0.21568627450980393
# rule: ['tomato', 'bottleguard', 'onion'] support: 0.11764705882352941 confidence: 0.11764705882352941
# rule: ['tid', 'potato', 'bottleguard'] support: 0.23529411764705882 confidence: 0.23529411764705882
# rule: ['tomato', 'potato', 'bottleguard'] support: 0.1568627450980392 confidence: 0.1568627450980392
# rule: ['tid', 'tomato', 'bottleguard'] support: 0.27450980392156865 confidence: 0.27450980392156865
# rule: ['tid', 'potato', 'onion'] support: 0.27450980392156865 confidence: 0.27450980392156865
# rule: ['tomato', 'potato', 'onion'] support: 0.17647058823529413 confidence: 0.17647058823529413
# rule: ['tid', 'tomato', 'onion'] support: 0.29411764705882354 confidence: 0.29411764705882354
# rule: ['tid', 'tomato', 'potato'] support: 0.29411764705882354 confidence: 0.29411764705882354
# rule: ['tid', 'beans', 'bottleguard', 'onion'] support: 0.11764705882352941 confidence: 0.11764705882352941
# rule: ['tid', 'beans', 'potato', 'bottleguard'] support: 0.11764705882352941 confidence: 0.11764705882352941
# rule: ['tid', 'beans', 'bottleguard', 'tomato'] support: 0.19607843137254902 confidence: 0.19607843137254902
# rule: ['tid', 'beans', 'potato', 'onion'] support: 0.13725490196078433 confidence: 0.13725490196078433
# rule: ['tid', 'beans', 'tomato', 'onion'] support: 0.13725490196078433 confidence: 0.13725490196078433
# rule: ['tid', 'beans', 'potato', 'tomato'] support: 0.1568627450980392 confidence: 0.1568627450980392
# rule: ['tid', 'potato', 'bottleguard', 'onion'] support: 0.13725490196078433 confidence: 0.13725490196078433
# rule: ['tid', 'tomato', 'bottleguard', 'onion'] support: 0.11764705882352941 confidence: 0.11764705882352941
# rule: ['tid', 'tomato', 'potato', 'bottleguard'] support: 0.1568627450980392 confidence: 0.1568627450980392
# rule: ['tid', 'tomato', 'potato', 'onion'] support: 0.17647058823529413 confidence: 0.17647058823529413

# %%
#p3

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
#from sklearn.preprocessing import MinMaxScaler



df1 = pd.read_csv('association_analysis.csv')
df1.head()
df1.drop(['tid'], axis = 1, inplace = True)
df1.head()

# # !pip install apyori

from apyori import apriori

records = []
for i in range(len(df1)):
    record = []
    for j in range(len(df1.columns)):
        if df1.values[i, j]:
            record.append(df1.columns[j])
    records.append(record)    
records[:3]

# print(records)


min_sup = 0.03
min_confidence = 0.7

rules = apriori(records, min_support = 0.03, min_confidence = 0.7)
for i in rules:
    print(f"{i[0]} {i[1]}  {i[2][0][2]}")
# for rule in rules:
#     items = [i for i in rule[0]]
#     print("Rule : ",items, "Support :", rule[1], "Confidence : ", rule[2][0][2])
# Out:
# frozenset({'beans', 'bottleguard', 'tomato'}) 0.19607843137254902  0.7692307692307693
# frozenset({'beans', 'potato', 'tomato'}) 0.1568627450980392  0.7272727272727272
# frozenset({'beans', 'potato', 'bottleguard', 'tomato'}) 0.09803921568627451  0.8333333333333334
# frozenset({'beans', 'potato', 'tomato', 'onion'}) 0.09803921568627451  0.7142857142857142
# frozenset({'tomato', 'potato', 'bottleguard', 'onion'}) 0.09803921568627451  0.7142857142857142
# frozenset({'beans', 'potato', 'tomato', 'onion', 'bottleguard'}) 0.058823529411764705  0.75

# %%
#p4

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
#from sklearn.preprocessing import MinMaxScaler


df1 = pd.read_csv('association_analysis.csv')
df1 = df1.bfill()

# !pip install pyfpgrowth
import pyfpgrowth as fpg

records = []
for i in range(len(df1)):
    record = []
    for j in range(len(df1.columns)):
        if df1.values[i, j]:
            record.append(df1.columns[j])
    records.append(record)

itemsets = fpg.find_frequent_patterns(records, 0.03)

fpg.generate_association_rules(itemsets, 0.7)
# Out:
# {('beans', 'bottleguard', 'onion'): (('tid',), 1.0),
#  ('beans', 'bottleguard', 'onion', 'potato'): (('tid', 'tomato'), 0.75),
#  ('bottleguard', 'onion', 'potato'): (('tid',), 1.0),
#  ('bottleguard', 'onion', 'tomato'): (('potato', 'tid'), 0.8333333333333334),
#  ('bottleguard', 'onion', 'potato', 'tid'): (('tomato',), 0.7142857142857143),
#  ('bottleguard', 'onion', 'potato', 'tomato'): (('tid',), 1.0),
#  ('bottleguard', 'onion', 'tid', 'tomato'): (('potato',), 0.8333333333333334),
#  ('beans', 'bottleguard', 'onion', 'tomato'): (('potato', 'tid'), 1.0),
#  ('beans', 'bottleguard', 'onion', 'potato', 'tid'): (('tomato',), 0.75),
#  ('beans', 'bottleguard', 'onion', 'potato', 'tomato'): (('tid',), 1.0),
#  ('beans', 'bottleguard', 'onion', 'tid', 'tomato'): (('potato',), 1.0),
#  ('beans', 'bottleguard', 'potato'): (('tid', 'tomato'), 0.8333333333333334),
#  ('beans', 'bottleguard', 'potato', 'tid'): (('tomato',), 0.8333333333333334),
#  ('beans', 'bottleguard', 'potato', 'tomato'): (('tid',), 1.0),
#  ('bottleguard', 'potato', 'tomato'): (('tid',), 1.0),
#  ('beans', 'bottleguard'): (('tid', 'tomato'), 0.7692307692307693),
#  ('bottleguard', 'tomato'): (('tid',), 1.0),
#  ('beans', 'bottleguard', 'tid'): (('tomato',), 0.7692307692307693),
#  ('beans', 'bottleguard', 'tomato'): (('tid',), 1.0),
#  ('bottleguard', 'tid', 'tomato'): (('beans',), 0.7142857142857143),
#  ('beans', 'onion', 'potato'): (('tid', 'tomato'), 0.7142857142857143),
#  ('beans', 'onion', 'tomato'): (('tid',), 1.0),
#  ('beans', 'onion', 'potato', 'tid'): (('tomato',), 0.7142857142857143),
#  ('beans', 'onion', 'potato', 'tomato'): (('tid',), 1.0),
#  ('beans', 'onion', 'tid', 'tomato'): (('potato',), 0.7142857142857143),
#  ('beans', 'potato', 'tid'): (('tomato',), 0.7272727272727273),
#  ('beans', 'potato', 'tomato'): (('tid',), 1.0),
#  ('beans', 'onion'): (('tid',), 1.0),
#  ('beans', 'tomato'): (('tid',), 1.0),
#  ('onion',): (('tid',), 1.0),
#  ('onion', 'tomato'): (('tid',), 1.0),
#  ('onion', 'potato'): (('tid',), 1.0),
#  ('onion', 'potato', 'tomato'): (('tid',), 1.0),
#  ('potato', 'tomato'): (('tid',), 1.0),
#  ('tomato',): (('tid',), 1.0)}

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


df = pd.read_csv('CustomerData.csv')
df = df.bfill()

df[['category', 'purchase type ', 'gender']] = df[['category', 'purchase type ', 'gender']].apply(LabelEncoder().fit_transform)
df.head()

features = df[['age', 'gender', 'annual income (lakhs)']]
target = df[['purchase type ']]

x_train, x_test, y_train, y_test = train_test_split(features, target, random_state = 0, test_size = 0.3)

from sklearn.tree import DecisionTreeClassifier

DTC = DecisionTreeClassifier()
DTC.fit(x_train, y_train)
predicted_labels = DTC.predict(x_test)
DTC.score(x_test, y_test)
print(DTC.score(x_test, y_test))

from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(y_test, predicted_labels))
# print(metrics.classification_report(y_test, predicted_labels))
# probability = classifierDT.predict_proba(x_test)[:, 1]
# print("Area under the curve:", metrics.roc_auc_score(y_test, probability))
fpr, tpr, threshold = metrics.roc_curve(y_test, probability)
# plt.xlabel('fpr')
# plt.ylabel('tpr')
plt.plot(fpr, tpr, color = 'orange')
plt.plot([0,1], [0, 1], linestyle='--')
plt.plot()
# Out:
# 0.6111111111111112
# Confusion Matrix
# [[5 4]
#  [3 6]]
# []
